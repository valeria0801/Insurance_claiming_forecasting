# %%
#Import data and libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,  LSTM
from tensorflow.keras import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Have a look at our data

# %%
data = pd.read_excel('../raw_data/data_daily_filter.xlsx', engine='openpyxl').drop(columns='Unnamed: 0')

# %%
data.head()
# Out:
#   date_issue  total_amount_claims
# 0 2018-09-01                  168
# 1 2018-09-02                  332
# 2 2018-09-03                 7185
# 3 2018-09-04                 4100
# 4 2018-09-05                 3497

# %%
# The value to predict is the column total_amount_claims. Let's define "y" and have a look at its trend

# %%
# length of data frame

# %%
len_data = len(data)
len_data
# Out:
# 917

# %%
# Select feature to predict

# %%
y = data['total_amount_claims']
y.head()
# Out:
# 0     168
# 1     332
# 2    7185
# 3    4100
# 4    3497
# Name: total_amount_claims, dtype: int64

# %%
# Convert feature to array

# %%
y = np.array(y)

# %%
y.shape
# Out:
# (917,)

# %%
y = y.reshape(-1,1)

# %%
y.shape
# Out:
# (917, 1)

# %%
# Plot y

# %%
plt.plot(y);

# %%
# We will use shifted versions of the column Y as independent variables, that is to say use 3 delays of Y
# as inputs to predict the output of our data.

# %%
X1 = y[0:len_data-6,:]
X2 = y[1:len_data-5,:]
X3 = y[2:len_data-4,:]
X4 = y[3:len_data-3,:]
X5 = y[4:len_data-2,:]
X6 = y[5:len_data-1,:]
y = y[6:len_data,:]

# %%
X1.size
# Out:
# 911

# %%
X2.size
# Out:
# 911

# %%
X3.size
# Out:
# 911

# %%
y.size
# Out:
# 911

# %%
X = np.concatenate([X1,X2,X3,X4,X5,X6],axis=1)

# %%
X
# Out:
# array([[   168,    332,   7185,   4100,   3497,    326],
#        [   332,   7185,   4100,   3497,    326,   1706],
#        [  7185,   4100,   3497,    326,   1706,    260],
#        ...,
#        [ 78381,  55910,  93081, 130873, 102035,  65304],
#        [ 55910,  93081, 130873, 102035,  65304, 208034],
#        [ 93081, 130873, 102035,  65304, 208034,  85163]])

# %%
print(f'X shape is {X.shape}')
print(f'Y shape is {y.shape}')
# Out:
# X shape is (911, 6)
# Y shape is (911, 1)

# %%
# we standardize our data both our variable x and our variable y between 0 and 1

# %%
# LSTM needs 3 dimensional input so we have to reshape the X input into 3 dimensions.

# %%
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

scaler.fit(y)
y = scaler.transform(y)

X= np.reshape(X, (X.shape[0],1,X.shape[1]))

# %%
X.shape
# Out:
# (911, 1, 6)

# %%
# Define training and test sets for our model

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
len_ = int(0.8*X.shape[0])
X_train = X[:len_,:,:]
X_test = X[len_:,:,:]
y_train = y[:len_,:]
y_test = y[len_:,:]

# %%
print(f'X train size:{X_train.shape}')
print(f'X test size:{X_test.shape}')
print(f'y train size:{y_train.shape}')
print(f'y test size:{y_test.shape}')
# Out:
# X train size:(728, 1, 6)
# X test size:(183, 1, 6)
# y train size:(728, 1)
# y test size:(183, 1)

# %%
# model building

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# %%
model = models.Sequential()
model.add(layers.LSTM(64, activation='tanh', return_sequences=False))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(8, activation='relu'))
model.add(layers.Dense(1, activation='linear'))

# %%
# We use mean absolute error to assess our model and then we fit our model to the training set and launch the prediction

# %%
model.compile(optimizer='RMSprop',
            loss='MeanSquaredError',
            metrics=['mse', 'mae', 'mape'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(patience=50, restore_best_weights=True)
model.fit(X_train, y_train,
        validation_split=0.2,
        epochs=200,
        verbose=1,
        batch_size=32,
        callbacks=[es]
        )
# Out:
# Epoch 1/200
# 19/19 [==============================] - 4s 67ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0345 - mape: 48515.4557 - val_loss: 0.0207 - val_mse: 0.0207 - val_mae: 0.0809 - val_mape: 130.1164
# Epoch 2/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0291 - mape: 31140.9615 - val_loss: 0.0192 - val_mse: 0.0192 - val_mae: 0.0756 - val_mape: 148.2779
# Epoch 3/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0334 - mape: 33797.1225 - val_loss: 0.0183 - val_mse: 0.0183 - val_mae: 0.0725 - val_mape: 156.1359
# Epoch 4/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0302 - mape: 23764.6748 - val_loss: 0.0200 - val_mse: 0.0200 - val_mae: 0.0787 - val_mape: 124.7535
# Epoch 5/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0324 - mape: 49450.6848 - val_loss: 0.0194 - val_mse: 0.0194 - val_mae: 0.0765 - val_mape: 145.0531
# Epoch 6/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0301 - mape: 8440.7139 - val_loss: 0.0183 - val_mse: 0.0183 - val_mae: 0.0726 - val_mape: 162.3336
# Epoch 7/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0321 - mape: 93422.0249 - val_loss: 0.0202 - val_mse: 0.0202 - val_mae: 0.0793 - val_mape: 141.8358
# Epoch 8/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0321 - mape: 86510.3715 - val_loss: 0.0198 - val_mse: 0.0198 - val_mae: 0.0778 - val_mape: 153.3486
# Epoch 9/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0347 - mape: 105203.9417 - val_loss: 0.0187 - val_mse: 0.0187 - val_mae: 0.0749 - val_mape: 178.5014
# Epoch 10/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0306 - mape: 140210.0818 - val_loss: 0.0194 - val_mse: 0.0194 - val_mae: 0.0765 - val_mape: 149.0437
# Epoch 11/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0337 - mape: 12314.7052 - val_loss: 0.0204 - val_mse: 0.0204 - val_mae: 0.0805 - val_mape: 129.6566
# Epoch 12/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0301 - mape: 68034.5950 - val_loss: 0.0210 - val_mse: 0.0210 - val_mae: 0.0822 - val_mape: 145.9049
# Epoch 13/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0325 - mape: 8257.5745 - val_loss: 0.0189 - val_mse: 0.0189 - val_mae: 0.0757 - val_mape: 175.9683
# Epoch 14/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0326 - mape: 33199.0410 - val_loss: 0.0182 - val_mse: 0.0182 - val_mae: 0.0743 - val_mape: 190.9635
# Epoch 15/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0339 - mape: 9714.6198 - val_loss: 0.0221 - val_mse: 0.0221 - val_mae: 0.0860 - val_mape: 141.9249
# Epoch 16/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0279 - mape: 58104.5060 - val_loss: 0.0191 - val_mse: 0.0191 - val_mae: 0.0762 - val_mape: 153.5577
# Epoch 17/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0326 - mape: 41385.1365 - val_loss: 0.0229 - val_mse: 0.0229 - val_mae: 0.0883 - val_mape: 148.8428
# Epoch 18/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0291 - mape: 46599.7000 - val_loss: 0.0214 - val_mse: 0.0214 - val_mae: 0.0842 - val_mape: 134.1214
# Epoch 19/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0326 - mape: 23427.5634 - val_loss: 0.0229 - val_mse: 0.0229 - val_mae: 0.0892 - val_mape: 130.9310
# Epoch 20/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0319 - mape: 8117.0832 - val_loss: 0.0195 - val_mse: 0.0195 - val_mae: 0.0791 - val_mape: 199.0520
# Epoch 21/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0345 - mape: 20748.7312 - val_loss: 0.0208 - val_mse: 0.0208 - val_mae: 0.0818 - val_mape: 167.6530
# Epoch 22/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0355 - mape: 19507.7711 - val_loss: 0.0222 - val_mse: 0.0222 - val_mae: 0.0861 - val_mape: 157.1579
# Epoch 23/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.
200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0297 - mape: 19975.8216 - val_loss: 0.0215 - val_mse: 0.0215 - val_mae: 0.0830 - val_mape: 158.1728
# Epoch 69/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0302 - mape: 44313.9161 - val_loss: 0.0229 - val_mse: 0.0229 - val_mae: 0.0882 - val_mape: 162.3366
# Epoch 70/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0356 - mape: 151967.9836 - val_loss: 0.0211 - val_mse: 0.0211 - val_mae: 0.0823 - val_mape: 166.1028
# Epoch 71/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0302 - mape: 10523.4381 - val_loss: 0.0216 - val_mse: 0.0216 - val_mae: 0.0837 - val_mape: 146.6657
# Epoch 72/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0304 - mape: 36884.7370 - val_loss: 0.0217 - val_mse: 0.0217 - val_mae: 0.0839 - val_mape: 160.9023
# Epoch 73/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0354 - mape: 42589.7490 - val_loss: 0.0215 - val_mse: 0.0215 - val_mae: 0.0833 - val_mape: 156.6227

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                18176
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 20,929
# Trainable params: 20,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_mae = model.evaluate(X_test, y_test, verbose=0)
print(f'Model Mean Absolute Error {model_mae[1]:.4f}')
# Out:
# Model Mean Absolute Error 0.0537

# %%
Predict = model.predict(X_test)

# %%
# Let’s now have a visualization comparing the prediction versus the test set to see how our model performed

# %%
plt.figure(figsize=(15,10))
plt.plot(y_test,label = 'Test')
plt.plot(Predict, label = 'Prediction')
plt.legend(loc='best')
plt.show()

# %%
# Let’s now add time indexes and scale back to the original scale

# %%
y_train = scaler.inverse_transform(y_train)

# %%
y_train = pd.DataFrame(y_train)
y_train.index = pd.to_datetime(data.iloc[6:734,0])
y_train
# Out:
#                   0
# date_issue
# 2018-09-07   1706.0
# 2018-09-08    260.0
# 2018-09-09     31.0
# 2018-09-10    204.0
# 2018-09-11  23453.0
# ...             ...
# 2020-09-02  26561.0
# 2020-09-03  51312.0
# 2020-09-04  35574.0
# 2020-09-05  23983.0
# 2020-09-06  18413.0
#
# [728 rows x 1 columns]

# %%
y_test = scaler.inverse_transform(y_test)

# %%
y_test = pd.DataFrame(y_test)
y_test.index = pd.to_datetime(data.iloc[734:,0])
y_test
# Out:
#                    0
# date_issue
# 2020-09-07   85999.0
# 2020-09-08   51568.0
# 2020-09-09   12203.0
# 2020-09-10   28497.0
# 2020-09-11   14784.0
# ...              ...
# 2021-03-04  102035.0
# 2021-03-05   65304.0
# 2021-03-06  208034.0
# 2021-03-07   85163.0
# 2021-03-08  108860.0
#
# [183 rows x 1 columns]

# %%
Predict = scaler.inverse_transform(Predict)

# %%
Predict = pd.DataFrame(Predict)
Predict.index=pd.to_datetime(data.iloc[734:,0])
Predict
# Out:
#                        0
# date_issue
# 2020-09-07  12972.968750
# 2020-09-08  17128.419922
# 2020-09-09  17562.751953
# 2020-09-10   9333.362305
# 2020-09-11  17926.738281
# ...                  ...
# 2021-03-04  10323.596680
# 2021-03-05   5707.909668
# 2021-03-06   8353.389648
# 2021-03-07  10068.492188
# 2021-03-08  14322.799805
#
# [183 rows x 1 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(y_test)
plt.plot(Predict)
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 3915218688.0000 - mse: 3915218688.0000 - mae: 51230.1094 - mape: 99.9998
# [3915218688.0, 3915218688.0, 51230.109375, 99.99976348876953]
