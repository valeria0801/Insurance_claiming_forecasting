# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ## Data Colectiva

# %%
# Reading Data
data = pd.read_excel('../raw_data/data_colec_full.xlsx', engine='openpyxl')
data.head()
# Out:
#    Unnamed: 0  status insurance_type  \
# 0           4  PAGADO      COLECTIVO
# 1           5  PAGADO      COLECTIVO
# 2           6  PAGADO      COLECTIVO
# 3           7  PAGADO      COLECTIVO
# 4           9  PAGADO      COLECTIVO
#
#                                              disease  claim_type  \
# 0                          Dolor Abdominal Y Pelvico  EMERGENCIA
# 1  Control General De Salud De Rutina De Subpobla...   REEMBOLSO
# 2  Quiste Folicular De La Piel Y Del Tejido Subcu...   REEMBOLSO
# 3  Control General De Salud De Rutina De Subpobla...   REEMBOLSO
# 4        Fractura De La Pierna, Inclusive El Tobillo   REEMBOLSO
#
#   provider_type                   state sex  age  country_id  amount  \
# 0       CLINICA                 Miranda   F   47          29      14
# 1  No Informado  Estado No Identificado   F   35          25     290
# 2  No Informado  Estado No Identificado   F   64          14     696
# 3  No Informado  Estado No Identificado   F   48          14      35
# 4  No Informado  Estado No Identificado   M   88          24     585
#
#   date_issue   age_range           h_type
# 0 2018-09-02       40-49      Ambulatorio
# 1 2018-09-03       30-39  Hospitalización
# 2 2018-09-03       60-69  Hospitalización
# 3 2018-09-03       40-49  Hospitalización
# 4 2018-09-03  Mayor a 70  Hospitalización

# %%
# Dropping extra index column
data = data.drop(columns= 'Unnamed: 0')

# %%
data.dtypes
# Out:
# status                    object
# insurance_type            object
# disease                   object
# claim_type                object
# provider_type             object
# state                     object
# sex                       object
# age                        int64
# country_id                 int64
# amount                     int64
# date_issue        datetime64[ns]
# age_range                 object
# h_type                    object
# dtype: object

# %%
data.disease.value_counts()
# Out:
# Hipertension Arterial Y Sus Complicaciones                      12710
# Bronquitis Aguda                                                 4206
# Control General De Salud De Rutina De Subpoblaciones Definid     3996
# Diarrea Y Gastroenteritis De Presunto Origen Infeccioso          3045
# Lumbalgia                                                        2745
#                                                                 ...
# Sarcoma De Kaposi                                                   1
# Tumor Benigno Del Oido Medio Y Del Sistema Respiratorio             1
# Toxoplasmosis                                                       1
# Hipertension Materna, No Especificada                               1
# Tumor Maligno Del Paladar                                           1
# Name: disease, Length: 524, dtype: int64

# %%
data['covid_claims'] = data.disease.map(lambda x: 1 if 'Covid' in x else 0)

# %%
data.covid_claims.value_counts()
# Out:
# 0    109170
# 1      2645
# Name: covid_claims, dtype: int64

# %%
data_daily = data.groupby('date_issue', as_index = False).agg({'amount': 'sum', 'covid_claims': 'sum'})
data_daily
# Out:
#     date_issue  amount  covid_claims
# 0   2018-09-02      14             0
# 1   2018-09-03    8716             0
# 2   2018-09-04   23504             0
# 3   2018-09-05   48112             0
# 4   2018-09-06   11508             0
# ..         ...     ...           ...
# 889 2021-03-04  174996            15
# 890 2021-03-05  180932            23
# 891 2021-03-06   69308            17
# 892 2021-03-07   42822            11
# 893 2021-03-08    2247             2
#
# [894 rows x 3 columns]

# %%
data_weekly = data_daily.resample('W-Mon', on='date_issue').sum().reset_index().sort_values(by='date_issue')
data_weekly
# Out:
#     date_issue   amount  covid_claims
# 0   2018-09-03     8730             0
# 1   2018-09-10   148950             0
# 2   2018-09-17   118735             0
# 3   2018-09-24   150795             0
# 4   2018-10-01    40850             0
# ..         ...      ...           ...
# 127 2021-02-08  1107180            96
# 128 2021-02-15  1048086           106
# 129 2021-02-22  1047364            94
# 130 2021-03-01  1328375           166
# 131 2021-03-08   937722            96
#
# [132 rows x 3 columns]

# %%
data['covid_claims'] = data.disease.map(lambda x: 1 if 'Covid' in x else 0)

# %%
data['covid_claims'].sum(data.amount)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9f9fe19fb239> in <module>
# ----> 1 data['covid_claims'].sum(data.amount)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11060             **kwargs,
#   11061         ):
# > 11062             return NDFrame.sum(
#   11063                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11064             )
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10782         **kwargs,
#   10783     ):
# > 10784         return self._min_count_stat_function(
#   10785             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10786         )
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10764                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   10765             )
# > 10766         return self._reduce(
#   10767             func,
#   10768             name=name,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4137
#    4138         if axis is not None:
# -> 4139             self._get_axis_number(axis)
#    4140
#    4141         if isinstance(delegate, ExtensionArray):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     455     def _get_axis_number(cls, axis: Axis) -> int:
#     456         try:
# --> 457             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     458         except KeyError:
#     459             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __hash__(self)
#    1780
#    1781     def __hash__(self) -> int:
# -> 1782         raise TypeError(
#    1783             f"{repr(type(self).__name__)} objects are mutable, "
#    1784             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
# Exporting to excel

daily_data_clean_with_covid_col = data_daily.to_excel('../raw_data/daily_data_clean_with_covid_col.xlsx', engine='xlsxwriter')
weekly_data_clean_with_covid_col = data_weekly.to_excel('../raw_data/weekly_data_clean_with_covid_col.xlsx', engine='xlsxwriter')

# %% [markdown]
# ## Data Individuos

# %%
# Reading Data
data = pd.read_excel('../raw_data/data_indiv_full.xlsx', engine='openpyxl')

# %%
data.head()
# Out:
#    Unnamed: 0  status insurance_type                         disease  \
# 0           0  PAGADO     INDIVIDUAL  Laringitis Y Traqueitis Agudas
# 1           1  PAGADO     INDIVIDUAL          Hepatitis Viral(A-B-C)
# 2           2  PAGADO     INDIVIDUAL       Amigdalo-Faringitis Aguda
# 3           3  PAGADO     INDIVIDUAL                Bronquitis Aguda
# 4           8  PAGADO     INDIVIDUAL              Gastritis (Simple)
#
#    claim_type provider_type                   state sex  age  country_id  \
# 0  EMERGENCIA       CLINICA        Distrito Capital   F   48          29
# 1  EMERGENCIA       CLINICA        Distrito Capital   F   50          29
# 2  EMERGENCIA       CLINICA                   Zulia   M   42          29
# 3  EMERGENCIA       CLINICA        Distrito Capital   F   59          29
# 4   REEMBOLSO  No Informado  Estado No Identificado   M   26          29
#
#    amount date_issue age_range           h_type
# 0      26 2018-09-01     40-49      Ambulatorio
# 1     142 2018-09-01     50-59      Ambulatorio
# 2      21 2018-09-02     40-49      Ambulatorio
# 3     311 2018-09-02     50-59  Hospitalización
# 4      18 2018-09-03     20-29  Hospitalización

# %%
# Dropping extra index column
data = data.drop(columns= 'Unnamed: 0')

# %%
data.dtypes
# Out:
# status                    object
# insurance_type            object
# disease                   object
# claim_type                object
# provider_type             object
# state                     object
# sex                       object
# age                        int64
# country_id                 int64
# amount                     int64
# date_issue        datetime64[ns]
# age_range                 object
# h_type                    object
# dtype: object

# %%
data.disease.value_counts()
# Out:
# Embarazo, Parto Y Puerperio                                  2455
# Hipertension Arterial Y Sus Complicaciones                   1835
# Infeccion Viral - Covid 19 Sospechoso                        1582
# Bronquitis Aguda                                             1200
# Diarrea Y Gastroenteritis De Presunto Origen Infeccioso       967
#                                                              ...
# Nistagmo Y Otros Movimientos Oculares Irregulares               1
# Tumor Maligno Del Esofago                                       1
# Convulsiones Del Recien Nacido                                  1
# Quistes De La Region Bucal, No Clasificados En Otra Parte       1
# Dermatopolimiositis                                             1
# Name: disease, Length: 446, dtype: int64

# %%
data['covid_claims'] = data.disease.map(lambda x: 1 if 'Covid' in x else 0)

# %%
data.covid_claims.value_counts()
# Out:
# 0    37537
# 1     1885
# Name: covid_claims, dtype: int64

# %%
data_daily = data.groupby('date_issue', as_index = False).agg({'amount': 'sum', 'covid_claims': 'sum'})
data_daily
# Out:
#     date_issue  amount  covid_claims
# 0   2018-09-01     168             0
# 1   2018-09-02     332             0
# 2   2018-09-03    7453             0
# 3   2018-09-04    5025             0
# 4   2018-09-05   16023             0
# ..         ...     ...           ...
# 914 2021-03-04  175724            27
# 915 2021-03-05  112495            22
# 916 2021-03-06  264350            21
# 917 2021-03-07   97002            15
# 918 2021-03-08  108860             1
#
# [919 rows x 3 columns]

# %%
amount = data_daily['covid_claims'].map(lambda x: sum(data_daily.amount) if data_daily['covid_claims'] > 0 else 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d9ac5da4c5e> in <module>
# ----> 1 amount = data_daily['covid_claims'].map(lambda x: sum(data_daily.amount) if data_daily['covid_claims'] > 0 else 0)
#
# NameError: name 'data_daily' is not defined

# %%
data_weekly = data_daily.resample('W-Mon', on='date_issue').sum().reset_index().sort_values(by='date_issue')
data_weekly
# Out:
#     date_issue   amount  covid_claims
# 0   2018-09-03     7953             0
# 1   2018-09-10    52824             0
# 2   2018-09-17   144926             0
# 3   2018-09-24   334429             0
# 4   2018-10-01   202143             0
# ..         ...      ...           ...
# 127 2021-02-08   745803            98
# 128 2021-02-15   677139            79
# 129 2021-02-22  1184838           113
# 130 2021-03-01  1130230           105
# 131 2021-03-08  1174264           131
#
# [132 rows x 3 columns]

# %%
# Exporting to excel

daily_data_clean_with_covid_ind = data_daily.to_excel('../raw_data/daily_data_clean_with_covid_ind.xlsx', engine='xlsxwriter')
weekly_data_clean_with_covid_ind = data_weekly.to_excel('../raw_data/weekly_data_clean_with_covid_ind.xlsx', engine='xlsxwriter')
