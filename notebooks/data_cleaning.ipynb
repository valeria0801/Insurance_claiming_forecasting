# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/valeriarevolledo/code/valeria0801/Insurance_claiming_forecasting/notebooks'

# %% [markdown]
# ##### Import Data

# %%
data = pd.read_csv('../raw_data/data_siniestros.csv', delimiter=';')
# Out:
# /Users/valeriarevolledo/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#         SINIESTRO ESTATUS      RAMOID  \
# 0               1  PAGADO   COLECTIVO
# 1               2  PAGADO   COLECTIVO
# 2               3  PAGADO   COLECTIVO
# 3               4  PAGADO   COLECTIVO
# 4               5  PAGADO   COLECTIVO
# ...           ...     ...         ...
# 183614     183615  PAGADO   COLECTIVO
# 183615     183616  PAGADO   COLECTIVO
# 183616     183617  PAGADO   COLECTIVO
# 183617     183618  PAGADO  INDIVIDUAL
# 183618     183619  PAGADO  INDIVIDUAL
#
#                                                ENFERMEDAD    TIPO_SIN  \
# 0                         Trastorno Interno De La Rodilla  CARTA AVAL
# 1                    Gonartrosis [Artrosis De La Rodilla]  CARTA AVAL
# 2                         Trastorno Interno De La Rodilla  CARTA AVAL
# 3          Traumatismo Superficial Del Hombro Y Del Brazo  CARTA AVAL
# 4                             Cervicalalgia/Hernia Discal  CARTA AVAL
# ...                                                   ...         ...
# ...
