# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/santiagochiesa/code/valeria0801/Insurance_claiming_forecasting/notebooks

# %%
pd.read_csv('../Insurance_claiming_forecasting/data/clean_data.csv')
# Out:
#         status insurance_type  \
# 0       PAGADO      COLECTIVO
# 1       PAGADO      COLECTIVO
# 2       PAGADO      COLECTIVO
# 3       PAGADO      COLECTIVO
# 4       PAGADO      COLECTIVO
# ...        ...            ...
# 151246  PAGADO      COLECTIVO
# 151247  PAGADO      COLECTIVO
# 151248  PAGADO      COLECTIVO
# 151249  PAGADO     INDIVIDUAL
# 151250  PAGADO     INDIVIDUAL
#
#                                                   disease  claim_type  \
# 0                         Trastorno Interno De La Rodilla  CARTA AVAL
# 1                    Gonartrosis [Artrosis De La Rodilla]  CARTA AVAL
# 2                         Trastorno Interno De La Rodilla  CARTA AVAL
# 3          Traumatismo Superficial Del Hombro Y Del Brazo  CARTA AVAL
# 4                             Cervicalalgia/Hernia Discal  CARTA AVAL
# ...                                                   ...         ...
# 151246                         Hiperplasia De La Prostata  CARTA AVAL
# ...
